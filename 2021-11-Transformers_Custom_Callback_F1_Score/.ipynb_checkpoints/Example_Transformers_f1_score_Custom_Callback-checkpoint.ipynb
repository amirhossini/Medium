# %% [markdown]
# # Custom Callback Functions for Transformers
# ### How to quantify F1-Score when fine-tuning pre-trained transformers for NLP tasks?
#
# #### Example

# %% [markdown]
# #### Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import transformers
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import Callback
import sklearn
from sklearn.metrics import confusion_matrix,f1_score,precision_score,recall_score 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

print(f"Tensorflow version: {tf.__version__}")
print(f"Sklearn version: {sklearn.__version__}")
print(f"Transformers version: {transformers.__version__}")

physical_devices = tf.config.list_physical_devices('GPU') 
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)
    
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Tensorflow version: 2.5.0
# Sklearn version: 1.0
# Transformers version: 4.11.3
# Num GPUs Available:  1

# %% [markdown]
# #### I/O Files & Params

# %%
fl_train        = './datasets/banking77/train.csv'
fl_test         = './datasets/banking77/test.csv'

checkpoint      ='distilbert-base-uncased'

experiment_grid = {
    'n_labels'  : [10],
    'n_train_inst': [10]
}

seed = 0
BIG_int = 10**21
n_epochs = 50

# %% [markdown]
# #### Functions

# %%
class Metrics(Callback):
    def __init__(self, validation_data):
        self.validation_data = validation_data
    
    def on_train_begin(self, logs={}):
        self.val_f1s = []
        
    def on_epoch_end(self, epoch, logs={}):
        val_predict = np.argmax(tf.nn.softmax(self.model.predict(self.validation_data[0]).logits),1)
        val_targ = self.validation_data[1]
        val_f1 = f1_score(val_targ, val_predict, average='macro')
        logs['val_f1'] = val_f1
        print (f'— val_f1: {round(val_f1,4)} ')
        return

def select_data_instances(train, test, col_label, n_labels=None, n_train_inst=None):
    if n_labels is None:
        n_labels = len(train.loc[:,col_label].unique())
    if n_train_inst is None:
        n_train_inst = BIG_int 
        
    select_labels = np.array(train.loc[:,col_label].value_counts()[0:n_labels].index)
    select_train  = train.loc[train[col_label].isin(select_labels),:].reset_index(drop=True)
    subset_train  = pd.DataFrame(columns=select_train.columns)
    for label in select_labels:
        temp_train   = select_train.loc[select_train[col_label]==label,:].reset_index(drop=True)
        select_indx  = np.random.choice(range(len(temp_train)),min(n_train_inst,len(temp_train)))
        temp_train   = temp_train.iloc[select_indx,:]
        subset_train = subset_train.append(temp_train)
    subset_train = subset_train.sample(frac=1).reset_index(drop=True)
    select_test  = test.loc[test[col_label].isin(select_labels),:].reset_index(drop=True)
    select_test  = select_test.sample(frac=1).reset_index(drop=True)
    return subset_train, select_test 

def factorize_data(train, test, col_label,return_keys=False):
    train_labels, levels = pd.factorize(train.loc[:,col_label])
    categs = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().index
    labels = pd.concat([train.loc[:,col_label],pd.Series(train_labels)],axis=1).groupby(col_label).mean().values.T[0]
    label_keys=dict(zip(categs,labels))
    test_labels = test.loc[:,col_label].map(lambda x: label_keys[x])
    train.loc[:,col_label]=train_labels
    test.loc[:,col_label]=test_labels
    if return_keys:
        return train, test, label_keys
    else:
        return train, test
    
def tokenize_encode_data(train,test,col_text,col_label,checkpoint,
                         truncation_flag=True, padding_flag=True, return_tensors_opt='np'):
    train_sentences = list(train.loc[:,col_text])
    test_sentences  = list(test.loc[:,col_text])
    train_labels    = list(train.loc[:,col_label])
    test_labels     = list(test.loc[:,col_label])
    tokenizer       = AutoTokenizer.from_pretrained(checkpoint)
    train_encodings = tokenizer(train_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    test_encodings  = tokenizer(test_sentences, truncation=truncation_flag,
                                padding=padding_flag, return_tensors=return_tensors_opt)
    return train_encodings.data, train_labels, test_encodings.data, test_labels 

def transformer_model_compile(checkpoint,n_labels,lr=5e-5):
    model = TFAutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=n_labels)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                  loss=SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
    return model

def transformer_model_fit(model, train_encodings, train_labels, test_encodings, test_labels,epochs=10,batch_size=64):
    history = model.fit(train_encodings,np.array(train_labels),epochs=epochs,batch_size=batch_size,
          validation_data=(test_encodings, np.array(test_labels)),callbacks=[Metrics(validation_data)])
    return history, model

# %%
np.random.seed(seed)
train_orig = pd.read_csv(fl_train)
test_orig  = pd.read_csv(fl_test)

iexp=0
for ilab in experiment_grid['n_labels']:
    compiled_model = transformer_model_compile(checkpoint,ilab)
    for i_ninst in experiment_grid['n_train_inst']:
        iexp+=1
        train, test = select_data_instances(train_orig, test_orig, 'category', ilab, i_ninst)
        train, test = factorize_data(train, test, 'category')
        
        train_encodings, train_labels, test_encodings, test_labels = tokenize_encode_data(train,test,'text',
                                                                                          'category',checkpoint)
        validation_data                                            =(test_encodings, np.array(test_labels))
        
        history, fitted_model = transformer_model_fit(compiled_model,train_encodings,train_labels,
                                                      test_encodings, test_labels,epochs=n_epochs)

        fig, axes   = plt.subplots(1,3,figsize=(15,5))
        epoch_range = np.arange(1,len(history.history['loss'])+1)
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['loss'],label='Training Loss')
        axes[0]   = sns.lineplot(ax=axes[0],x=epoch_range,y=history.history['val_loss'],label='Validation Loss').set_title('Loss')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['accuracy'],label='Training Accuracy')
        axes[1]   = sns.lineplot(ax=axes[1],x=epoch_range,y=history.history['val_accuracy'],label='Validation Accuracy').set_title('Accuracy')
        axes[2]   = sns.lineplot(ax=axes[2],x=epoch_range,y=history.history['val_f1'],label='Validation f1_score(macro)').set_title('f1_score')
        axes[1].set_ylim=(0, 1)
        axes[2].set_ylim=(0, 1)
        _         = plt.show()
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertForSequenceClassification: ['vocab_layer_norm', 'vocab_transform', 'vocab_projector', 'activation_13']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFDistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier', 'dropout_19', 'pre_classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Windows\anaconda3\envs\tf2.5\lib\site-packages\tensorflow\python\ops\array_ops.py:5043: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# 2/2 [==============================] - 8s 2s/step - loss: 2.3075 - accuracy: 0.0900 - val_loss: 2.2909 - val_accuracy: 0.1650
# — val_f1: 0.1011
# Epoch 2/50
# 2/2 [==============================] - 1s 1s/step - loss: 2.2843 - accuracy: 0.1600 - val_loss: 2.2726 - val_accuracy: 0.2300
# — val_f1: 0.1659
# Epoch 3/50
# 2/2 [==============================] - 1s 1s/step - loss: 2.2317 - accuracy: 0.3900 - val_loss: 2.2444 - val_accuracy: 0.2425
# — val_f1: 0.2014
# Epoch 4/50
# 2/2 [==============================] - 1s 1s/step - loss: 2.1684 - accuracy: 0.4800 - val_loss: 2.2000 - val_accuracy: 0.3175
# — val_f1: 0.2963
# Epoch 5/50
# 2/2 [==============================] - 1s 1s/step - loss: 2.0869 - accuracy: 0.5800 - val_loss: 2.1369 - val_accuracy: 0.4850
# — val_f1: 0.4869
# Epoch 6/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.9999 - accuracy: 0.8200 - val_loss: 2.0639 - val_accuracy: 0.5550
# — val_f1: 0.5693
# Epoch 7/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.8848 - accuracy: 0.8800 - val_loss: 1.9892 - val_accuracy: 0.5875
# — val_f1: 0.6044
# Epoch 8/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.7700 - accuracy: 0.8900 - val_loss: 1.9050 - val_accuracy: 0.6275
# — val_f1: 0.6424
# Epoch 9/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.6392 - accuracy: 0.9300 - val_loss: 1.8189 - val_accuracy: 0.6525
# — val_f1: 0.6652
# Epoch 10/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.5249 - accuracy: 0.9600 - val_loss: 1.7230 - val_accuracy: 0.6700
# — val_f1: 0.6785
# Epoch 11/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.4076 - accuracy: 0.9700 - val_loss: 1.6278 - val_accuracy: 0.7000
# — val_f1: 0.7056
# Epoch 12/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.2623 - accuracy: 0.9800 - val_loss: 1.5322 - val_accuracy: 0.7175
# — val_f1: 0.7206
# Epoch 13/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.1247 - accuracy: 0.9900 - val_loss: 1.4380 - val_accuracy: 0.7275
# — val_f1: 0.7291
# Epoch 14/50
# 2/2 [==============================] - 1s 1s/step - loss: 1.0164 - accuracy: 0.9900 - val_loss: 1.3478 - val_accuracy: 0.7375
# — val_f1: 0.7383
# Epoch 15/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.8964 - accuracy: 0.9900 - val_loss: 1.2656 - val_accuracy: 0.7425
# — val_f1: 0.7429
# Epoch 16/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.7950 - accuracy: 0.9900 - val_loss: 1.1850 - val_accuracy: 0.7600
# — val_f1: 0.7598
# Epoch 17/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.6957 - accuracy: 1.0000 - val_loss: 1.0995 - val_accuracy: 0.7750
# — val_f1: 0.7742
# Epoch 18/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.6213 - accuracy: 1.0000 - val_loss: 1.0281 - val_accuracy: 0.7900
# — val_f1: 0.7895
# Epoch 19/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.5375 - accuracy: 1.0000 - val_loss: 0.9655 - val_accuracy: 0.7975
# — val_f1: 0.7963
# Epoch 20/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.4685 - accuracy: 1.0000 - val_loss: 0.9125 - val_accuracy: 0.8050
# — val_f1: 0.8035
# Epoch 21/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.4096 - accuracy: 1.0000 - val_loss: 0.8686 - val_accuracy: 0.7975
# — val_f1: 0.7968
# Epoch 22/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.3584 - accuracy: 1.0000 - val_loss: 0.8244 - val_accuracy: 0.8050
# — val_f1: 0.8046
# Epoch 23/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.3040 - accuracy: 1.0000 - val_loss: 0.7820 - val_accuracy: 0.8100
# — val_f1: 0.8094
# Epoch 24/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.2840 - accuracy: 1.0000 - val_loss: 0.7488 - val_accuracy: 0.8250
# — val_f1: 0.8242
# Epoch 25/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.2456 - accuracy: 1.0000 - val_loss: 0.7195 - val_accuracy: 0.8300
# — val_f1: 0.8288
# Epoch 26/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.2230 - accuracy: 1.0000 - val_loss: 0.6956 - val_accuracy: 0.8200
# — val_f1: 0.819
# Epoch 27/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1955 - accuracy: 1.0000 - val_loss: 0.6779 - val_accuracy: 0.8250
# — val_f1: 0.8241
# Epoch 28/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1785 - accuracy: 1.0000 - val_loss: 0.6586 - val_accuracy: 0.8300
# — val_f1: 0.8295
# Epoch 29/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1634 - accuracy: 1.0000 - val_loss: 0.6404 - val_accuracy: 0.8400
# — val_f1: 0.8398
# Epoch 30/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1437 - accuracy: 1.0000 - val_loss: 0.6266 - val_accuracy: 0.8425
# — val_f1: 0.8423
# Epoch 31/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1352 - accuracy: 1.0000 - val_loss: 0.6124 - val_accuracy: 0.8450
# — val_f1: 0.8448
# Epoch 32/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1227 - accuracy: 1.0000 - val_loss: 0.5978 - val_accuracy: 0.8525
# — val_f1: 0.8521
# Epoch 33/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1127 - accuracy: 1.0000 - val_loss: 0.5861 - val_accuracy: 0.8475
# — val_f1: 0.8466
# Epoch 34/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1028 - accuracy: 1.0000 - val_loss: 0.5782 - val_accuracy: 0.8475
# — val_f1: 0.8466
# Epoch 35/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.1004 - accuracy: 1.0000 - val_loss: 0.5740 - val_accuracy: 0.8450
# — val_f1: 0.8438
# Epoch 36/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0914 - accuracy: 1.0000 - val_loss: 0.5710 - val_accuracy: 0.8425
# — val_f1: 0.8415
# Epoch 37/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0840 - accuracy: 1.0000 - val_loss: 0.5669 - val_accuracy: 0.8400
# — val_f1: 0.8391
# Epoch 38/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0792 - accuracy: 1.0000 - val_loss: 0.5618 - val_accuracy: 0.8450
# — val_f1: 0.8441
# Epoch 39/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0731 - accuracy: 1.0000 - val_loss: 0.5570 - val_accuracy: 0.8475
# — val_f1: 0.8469
# Epoch 40/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0723 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.8500
# — val_f1: 0.8494
# Epoch 41/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0676 - accuracy: 1.0000 - val_loss: 0.5457 - val_accuracy: 0.8500
# — val_f1: 0.8494
# Epoch 42/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0649 - accuracy: 1.0000 - val_loss: 0.5405 - val_accuracy: 0.8525
# — val_f1: 0.8518
# Epoch 43/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.5350 - val_accuracy: 0.8500
# — val_f1: 0.849
# Epoch 44/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0551 - accuracy: 1.0000 - val_loss: 0.5312 - val_accuracy: 0.8525
# — val_f1: 0.8517
# Epoch 45/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.5291 - val_accuracy: 0.8525
# — val_f1: 0.8517
# Epoch 46/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.5281 - val_accuracy: 0.8500
# — val_f1: 0.8493
# Epoch 47/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0491 - accuracy: 1.0000 - val_loss: 0.5270 - val_accuracy: 0.8475
# — val_f1: 0.8467
# Epoch 48/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0471 - accuracy: 1.0000 - val_loss: 0.5260 - val_accuracy: 0.8450
# — val_f1: 0.8443
# Epoch 49/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.5255 - val_accuracy: 0.8475
# — val_f1: 0.8467
# Epoch 50/50
# 2/2 [==============================] - 1s 1s/step - loss: 0.0455 - accuracy: 1.0000 - val_loss: 0.5249 - val_accuracy: 0.8500
# — val_f1: 0.8493
